# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from pandas import DataFrame
import urllib
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv("311_service_requests_2017.csv", dtype=object)

# %%
df['open_dt'] = pd.to_datetime(df['open_dt'], errors='coerce')

# %%
df.head()
# Out:
#   case_enquiry_id             open_dt            target_dt  \
# 0    101001979518 2017-01-01 00:33:05  2017-01-04 08:30:00
# 1    101001979520 2017-01-01 01:22:52  2017-01-04 08:30:00
# 2    101001979521 2017-01-01 01:24:00  2017-01-18 08:30:00
# 3    101001979523 2017-01-01 02:24:00  2017-03-09 08:30:00
# 4    101001979524 2017-01-01 02:27:00  2017-01-31 02:27:26
#
#              closed_dt   ontime case_status  \
# 0  2017-01-02 23:48:15   ONTIME      Closed
# 1  2017-01-02 23:52:13   ONTIME      Closed
# 2  2017-01-05 15:10:54   ONTIME      Closed
# 3  2017-01-09 08:09:05   ONTIME      Closed
# 4                  NaN  OVERDUE        Open
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : 2017-01-02 23:48:15...
# 1  Case Closed. Closed date : 2017-01-02 23:52:13...
# 2  Case Closed. Closed date : 2017-01-05 15:10:54...
# 3  Case Closed. Closed date : 2017-01-09 08:09:05...
# 4
#
#                        case_title                            subject  \
# 0             Parking Enforcement  Transportation - Traffic Division
# 1             Parking Enforcement  Transportation - Traffic Division
# 2   PRINTED : Street light out RT            Public Works Department
# 3                Graffiti Removal                Property Management
# 4  Heat - Excessive  Insufficient              Inspectional Services
#
#                              reason  ... police_district  \
# 0  Enforcement & Abandoned Vehicles  ...              C6
# 1  Enforcement & Abandoned Vehicles  ...             E13
# 2                     Street Lights  ...             E13
# 3                          Graffiti  ...              D4
# 4                           Housing  ...              B2
#
#                              neighborhood neighborhood_services_district  \
# 0  South Boston / South Boston Waterfront                              5
# 1                           Jamaica Plain                             11
# 2                           Jamaica Plain                             11
# 3                                 Roxbury                             13
# 4                              Dorchester                             13
#
#       ward precinct               location_street_name location_zipcode  \
# 0   Ward 6     0609                     911 E Broadway            02127
# 1       19     1909  INTERSECTION Centre St & South St              NaN
# 2       19     1906                     20 Alveston St            02130
# 3       09     0904               1002-1004 Tremont St            02120
# 4  Ward 13     1305                    65 Monadnock St            02125
#
#   latitude longitude                source
# 0  42.3356  -71.0275  Citizens Connect App
# 1  42.3594  -71.0587  Citizens Connect App
# 2  42.3104  -71.1121  Citizens Connect App
# 3  42.3368  -71.0846  Citizens Connect App
# 4  42.3149  -71.0697      Constituent Call
#
# [5 rows x 29 columns]

# %%
leaflet1 = df[["type","latitude","longitude"]]

# %%
leaflet2 = leaflet1.loc[df['type'].isin([ 'Loud Parties/Music/People', 'Dumpster & Loading Noise Disturbances' , 'Work Hours-Loud Noise Complaints' , 'Undefined Noise Disturbance' , 'Automotive Noise Disturbance'])]

# %%
leaflet2.head()
# Out:
#                                        type latitude longitude
# 109               Loud Parties/Music/People  42.2629  -71.1163
# 2200  Dumpster & Loading Noise Disturbances  42.3468  -71.1057
# 3586       Work Hours-Loud Noise Complaints  42.3457  -71.0863
# 4907            Undefined Noise Disturbance  42.3594  -71.0587
# 5746       Work Hours-Loud Noise Complaints  42.3448  -71.0664

# %%
leaflet2.to_csv(("Noise_LatLong"))

# %%
df1 = df[["open_dt","type"]]

# %%
df1.head()
# Out:
#               open_dt                            type
# 0 2017-01-01 00:33:05             Parking Enforcement
# 1 2017-01-01 01:22:52             Parking Enforcement
# 2 2017-01-01 01:24:00            Street Light Outages
# 3 2017-01-01 02:24:00                Graffiti Removal
# 4 2017-01-01 02:27:00  Heat - Excessive  Insufficient

# %%
df1.type.unique()
# Out:
# array(['Parking Enforcement', 'Street Light Outages', 'Graffiti Removal',
#        'Heat - Excessive  Insufficient', 'Schedule a Bulk Item Pickup',
#        'Traffic Signal Inspection', 'Requests for Street Cleaning',
#        'Notification', 'Aircraft Noise Disturbance',
#        'Poor Conditions of Property', 'Sign Repair',
#        'Missed Trash/Recycling/Yard Waste/Bulk Item',
#        'Pick up Dead Animal', 'Schedule a Bulk Item Pickup SS',
#        'Improper Storage of Trash (Barrels)', 'Needle Pickup',
#        'Ground Maintenance', 'Abandoned Vehicles', 'Empty Litter Basket',
#        'PWD Graffiti', 'Street Light Knock Downs', 'Equipment Repair',
#        'Animal Generic Request', 'Sidewalk Repair (Make Safe)',
#        'New Sign  Crosswalk or Pavement Marking', 'Abandoned Bicycle',
#        'Tree Maintenance Requests', 'Request for Pothole Repair',
#        'Rodent Activity', 'Loud Parties/Music/People',
#        'Request for Snow Plowing', 'Illegal Occupancy',
#        'Unsafe Dangerous Conditions', 'Pest Infestation - Residential',
#        'General Comments For a Program or Policy', 'Illegal Dumping',
#        'CE Collection', 'Traffic Signal Repair',
#        'Mice Infestation - Residential', 'Contractors Complaint',
#        'Catchbasin', 'Sticker Request', 'Work w/out Permit',
#        'Unshoveled Sidewalk', 'No Utilities Residential - Water',
#        'Unsatisfactory Utilities - Electrical  Plumbing',
#        'Watermain Break', 'Zoning', 'New Tree Requests',
#        'Trash on Vacant Lot', 'Recycling Cart Return',
#        'Recycling Cart Inquiry', 'Unsanitary Conditions - Food',
#        'Parks Lighting/Electrical Issues', 'Animal Lost',
#        'Requests for Traffic Signal Studies or Reviews',
#        'Building Inspection Request', 'Contractor Complaints',
#        'Abandoned Building', 'General Lighting Request',
#        'Pavement Marking Maintenance', 'Animal Found', 'Sidewalk Repair',
#        'General Comments For An Employee', 'Electrical',
#        'Illegal Rooming House', 'Plumbing', 'Mechanical',
#        'Bicycle Issues', 'No-Tow Complaint Confirmation', 'Missing Sign',
#        'Overflowing or Un-kept Dumpster', 'Parking Meter Repairs',
#        'Food Alert - Unconfirmed', 'Install New Lighting',
#        'Unsatisfactory Living Conditions', 'Maintenance - Homeowner',
#        'Exceeding Terms of Permit', 'Tree Emergencies',
#        'Knockdown Replacement', 'Chronic Dampness/Mold', 'Call Log',
#        'Construction Debris', 'Working Beyond Hours',
#        'Protection of Adjoining Property',
#        'Parking on Front/Back Yards (Illegal Parking)',
#        'Unsanitary Conditions - Establishment', 'Space Savers',
#        'Major System Failure', 'Utility Casting Repair',
#        'Misc. Snow Complaint', 'BWSC Pothole',
#        'Transportation General Request', 'Illegal Posting of Signs',
#        'Request for Litter Basket Installation',
#        'Public Works General Request', 'Upgrade Existing Lighting',
#        'Sidewalk Cover / Manhole', 'Park Improvement Requests',
#        'Big Buildings Recycling (INTERNAL)', 'StreetLight Pole WO',
#        'Dumpster & Loading Noise Disturbances',
#        'Maintenance Complaint - Residential', 'Illegal Vending',
#        'Fire Hydrant', 'Heat/Fuel Assistance', 'Roadway Repair',
#        'BWSC General Request', 'Cross Metering - Sub-Metering',
#        'Food Alert - Confirmed',
#        'Request for Snow Plowing (Emergency Responder)',
#        'Product Short Measure', 'Scanning Overcharge', 'Carbon Monoxide',
#        'Sign Shop WO', 'Bed Bugs', 'Cemetery Maintenance Request',
#        'Work Hours-Loud Noise Complaints', 'City/State Snow Issues',
#        'Alert Boston', 'Rooftop & Mechanical Disturbances',
#        'General Traffic Engineering Request',
#        'Undefined Noise Disturbance', 'Request for Recycling Cart',
#        'Breathe Easy', 'Egress', 'Parks General Request',
#        'Bridge Maintenance', 'Tree in Park',
#        'No Utilities - Food Establishment - Water',
#        'Unsanitary Conditions - Employees', 'Utility Call-In',
#        'Overcrowding', 'Lead', 'Pigeon Infestation',
#        'Big Buildings Online Request', 'Illegal Use',
#        'Illegal Auto Body Shop', 'No Utilities Residential - Electricity',
#        'Litter Basket Maintenance',
#        'Requests for Directional or Roadway Changes',
#        'Unit Pricing Wrong/Missing', 'No Price on Gas/Wrong Price',
#        'No Utilities Residential - Gas', 'Sewage/Septic Back-Up',
#        'Short Measure - Gas', 'Squalid Living Conditions',
#        'Item Price Missing', 'Municipal Parking Lot Complaints',
#        'No Utilities - Food Establishment - Sewer',
#        'Animal Noise Disturbances', 'Fire in Food Establishment',
#        'Phone Bank Service Inquiry', 'Rental Unit Delivery Conditions',
#        'No Utilities - Food Establishment - Electricity',
#        'Pavement Marking Inspection', 'Automotive Noise Disturbance',
#        'Occupying W/Out A Valid CO/CI', 'Snow Emergency',
#        'Fire Department Request', 'Rat Bite', 'Planting',
#        'Billing Complaint', 'Snow/Ice Control', 'News Boxes',
#        'New Tree Warrantee Inspection', 'Capital Improvement Long Term',
#        'Private Parking Lot Complaints', 'Pickup/Clear Conduit',
#        'Valet Parking Problems', 'Public Events Noise Disturbances',
#        'Mosquitoes (West Nile)', 'Poor Ventilation', 'Scale Not Visible',
#        'Street Light Longterm Repair',
#        'No Utilities - Food Establishment - Flood',
#        'Student Move-in Issues', 'HP Sign Application New'], dtype=object)

# %%
month = df['Month'] = df['open_dt'].dt.month

# %%
month.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: open_dt, dtype: int64

# %%
final = pd.merge(df1, month, left_index=True, right_index=True)

# %%
final.head()
# Out:
#             open_dt_x                            type  open_dt_y
# 0 2017-01-01 00:33:05             Parking Enforcement          1
# 1 2017-01-01 01:22:52             Parking Enforcement          1
# 2 2017-01-01 01:24:00            Street Light Outages          1
# 3 2017-01-01 02:24:00                Graffiti Removal          1
# 4 2017-01-01 02:27:00  Heat - Excessive  Insufficient          1

# %%
df = final[["type", "open_dt_y"]]

# %%
df
# Out:
#                                                type  open_dt_y
# 0                               Parking Enforcement          1
# 1                               Parking Enforcement          1
# 2                              Street Light Outages          1
# 3                                  Graffiti Removal          1
# 4                    Heat - Excessive  Insufficient          1
# 5                       Schedule a Bulk Item Pickup          1
# 6                         Traffic Signal Inspection          1
# 7                               Parking Enforcement          1
# 8                      Requests for Street Cleaning          1
# 9                               Parking Enforcement          1
# 10                                     Notification          1
# 11                       Aircraft Noise Disturbance          1
# 12                      Poor Conditions of Property          1
# 13                      Poor Conditions of Property          1
# 14                      Poor Conditions of Property          1
# 15                      Poor Conditions of Property          1
# 16                              Parking Enforcement          1
# 17                        Traffic Signal Inspection          1
# 18                                      Sign Repair          1
# 19      Missed Trash/Recycling/Yard Waste/Bulk Item          1
# 20                              Pick up Dead Animal          1
# 21                              Parking Enforcement          1
# 22                   Schedule a Bulk Item Pickup SS          1
# 23              Improper Storage of Trash (Barrels)          1
# 24                                    Needle Pickup          1
# 25                     Requests for Street Cleaning          1
# 26                              Parking Enforcement          1
# 27                                    Needle Pickup          1
# 28              Improper Storage of Trash (Barrels)          1
# 29                               Ground Maintenance          1
# ...                                             ...        ...
# 251465                 Requests for Street Cleaning         12
# 251466               Heat - Excessive  Insufficient         12
# 251467                          Parking Enforcement         12
# 251468                          Parking Enforcement         12
# 251469                          Parking Enforcement         12
# 251470                                 Notification         12
# 251471                          Parking Enforcement         12
# 251472             No Utilities Residential - Water         12
# 251473                          Parking Enforcement         12
# 251474                          Parking Enforcement         12
# 251475                          Parking Enforcement         12
# 251476                          Parking Enforcement         12
# 251477                          Unshoveled Sidewalk         12
# 251478                   Request for Pothole Repair         12
# 251479                         Street Light Outages         12
# 251480               Heat - Excessive  Insufficient         12
# 251481               Heat - Excessive  Insufficient         12
# 251482                 Requests for Street Cleaning         12
# 251483                                 PWD Graffiti         12
# 251484                          Parking Enforcement         12
# 251485                          Parking Enforcement         12
# 251486                          Parking Enforcement         12
# 251487                          Unshoveled Sidewalk         12
# 251488                          Unshoveled Sidewalk         12
# 251489                          Parking Enforcement         12
# 251490                          Unshoveled Sidewalk         12
# 251491                          Parking Enforcement         12
# 251492                  Poor Conditions of Property         12
# 251493               Schedule a Bulk Item Pickup SS         12
# 251494                          Parking Enforcement         12
#
# [251495 rows x 2 columns]

# %%
df_2 = df.loc[df['type'].isin([ 'Loud Parties/Music/People', 'Dumpster & Loading Noise Disturbances' , 'Work Hours-Loud Noise Complaints' , 'Undefined Noise Disturbance' , 'Automotive Noise Disturbance'])]

# %%
df_2
# Out:
#                                          type  open_dt_y
# 109                 Loud Parties/Music/People          1
# 2200    Dumpster & Loading Noise Disturbances          1
# 3586         Work Hours-Loud Noise Complaints          1
# 4907              Undefined Noise Disturbance          1
# 5746         Work Hours-Loud Noise Complaints          1
# 6910                Loud Parties/Music/People          1
# 7163         Work Hours-Loud Noise Complaints          1
# 7173    Dumpster & Loading Noise Disturbances          1
# 7202         Work Hours-Loud Noise Complaints          1
# 7591                Loud Parties/Music/People          1
# 7607    Dumpster & Loading Noise Disturbances          1
# 7610    Dumpster & Loading Noise Disturbances          1
# 7625                Loud Parties/Music/People          1
# 7824         Work Hours-Loud Noise Complaints          1
# 8721         Work Hours-Loud Noise Complaints          1
# 8736    Dumpster & Loading Noise Disturbances          1
# 9897    Dumpster & Loading Noise Disturbances          1
# 9978         Work Hours-Loud Noise Complaints          1
# 10145        Work Hours-Loud Noise Complaints          1
# 10174        Work Hours-Loud Noise Complaints          1
# 10458        Work Hours-Loud Noise Complaints          1
# 10650        Work Hours-Loud Noise Complaints          1
# 10783             Undefined Noise Disturbance          1
# 10841               Loud Parties/Music/People          1
# 10923   Dumpster & Loading Noise Disturbances          1
# 11132        Work Hours-Loud Noise Complaints          1
# 13088             Undefined Noise Disturbance          1
# 13100        Work Hours-Loud Noise Complaints          1
# 13489        Work Hours-Loud Noise Complaints          1
# 13525        Work Hours-Loud Noise Complaints          1
# ...                                       ...        ...
# 233439           Automotive Noise Disturbance         11
# 233446              Loud Parties/Music/People         11
# 233657  Dumpster & Loading Noise Disturbances         11
# 234127           Automotive Noise Disturbance         12
# 234354            Undefined Noise Disturbance         12
# 234423       Work Hours-Loud Noise Complaints         12
# 234691       Work Hours-Loud Noise Complaints         12
# 234735       Work Hours-Loud Noise Complaints         12
# 235395       Work Hours-Loud Noise Complaints         12
# 235409  Dumpster & Loading Noise Disturbances         12
# 235533       Work Hours-Loud Noise Complaints         12
# 235663       Work Hours-Loud Noise Complaints         12
# 236208       Work Hours-Loud Noise Complaints         12
# 236458  Dumpster & Loading Noise Disturbances         12
# 236474           Automotive Noise Disturbance         12
# 236701           Automotive Noise Disturbance         12
# 236889              Loud Parties/Music/People         12
# 237781       Work Hours-Loud Noise Complaints         12
# 239387            Undefined Noise Disturbance         12
# 239835  Dumpster & Loading Noise Disturbances         12
# 241617       Work Hours-Loud Noise Complaints         12
# 243176            Undefined Noise Disturbance         12
# 243628              Loud Parties/Music/People         12
# 243803       Work Hours-Loud Noise Complaints         12
# 244421       Work Hours-Loud Noise Complaints         12
# 244424              Loud Parties/Music/People         12
# 245051       Work Hours-Loud Noise Complaints         12
# 245761           Automotive Noise Disturbance         12
# 247188            Undefined Noise Disturbance         12
# 247296              Loud Parties/Music/People         12
#
# [596 rows x 2 columns]

# %%
groupby_df = df_2.groupby('open_dt_y').count()
groupby_df
# Out:
#            type
# open_dt_y
# 1            43
# 2            47
# 3            35
# 4            61
# 5            59
# 6            34
# 7            43
# 8            68
# 9            73
# 10           49
# 11           57
# 12           27

# %%
df = pd.DataFrame({'month':['Jan', 'Feb', ' Mar', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec'], 'noise_complaints':[43, 47, 35, 61, 59, 34, 43, 68, 73, 49, 57, 27]})
ax = df.plot.bar(x='month', y='noise_complaints', rot=0)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df.to_csv('noise_monthly.csv')
