# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from pandas import DataFrame
import urllib
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv("311_service_requests_2017.csv", dtype=object)

# %%
df['open_dt'] = pd.to_datetime(df['open_dt'], errors='coerce')

# %%
df.head()
# Out:
#   case_enquiry_id             open_dt            target_dt  \
# 0    101001979518 2017-01-01 00:33:05  2017-01-04 08:30:00
# 1    101001979520 2017-01-01 01:22:52  2017-01-04 08:30:00
# 2    101001979521 2017-01-01 01:24:00  2017-01-18 08:30:00
# 3    101001979523 2017-01-01 02:24:00  2017-03-09 08:30:00
# 4    101001979524 2017-01-01 02:27:00  2017-01-31 02:27:26
#
#              closed_dt   ontime case_status  \
# 0  2017-01-02 23:48:15   ONTIME      Closed
# 1  2017-01-02 23:52:13   ONTIME      Closed
# 2  2017-01-05 15:10:54   ONTIME      Closed
# 3  2017-01-09 08:09:05   ONTIME      Closed
# 4                  NaN  OVERDUE        Open
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : 2017-01-02 23:48:15...
# 1  Case Closed. Closed date : 2017-01-02 23:52:13...
# 2  Case Closed. Closed date : 2017-01-05 15:10:54...
# 3  Case Closed. Closed date : 2017-01-09 08:09:05...
# 4
#
# ...

# %%
df1 = df[["open_dt","neighborhood","reason"]]

# %%
df1.head()
# Out:
#               open_dt                            neighborhood  \
# 0 2017-01-01 00:33:05  South Boston / South Boston Waterfront
# 1 2017-01-01 01:22:52                           Jamaica Plain
# 2 2017-01-01 01:24:00                           Jamaica Plain
# 3 2017-01-01 02:24:00                                 Roxbury
# 4 2017-01-01 02:27:00                              Dorchester
#
#                              reason
# 0  Enforcement & Abandoned Vehicles
# 1  Enforcement & Abandoned Vehicles
# 2                     Street Lights
# 3                          Graffiti
# 4                           Housing

# %%
df1.reason.unique()
# Out:
# array(['Enforcement & Abandoned Vehicles', 'Street Lights', 'Graffiti',
#        'Housing', 'Sanitation', 'Signs & Signals', 'Street Cleaning',
#        'Notification', 'Massport', 'Code Enforcement', 'Needle Program',
#        'Park Maintenance & Safety', 'Highway Maintenance',
#        'Animal Issues', 'Abandoned Bicycle', 'Trees',
#        'Environmental Services', 'Noise Disturbance', 'Building',
#        'Employee & General Comments', 'Catchbasin', 'Recycling',
#        'Water Issues', 'Health', 'Traffic Management & Engineering',
#        'Operations', 'Boston Bikes', 'Administrative & General Requests',
#        'Disability', 'Pothole', 'Sidewalk Cover / Manhole',
#        'Neighborhood Services Issues', 'Fire Hydrant', 'Programs',
#        'Weights and Measures', 'Cemetery', 'Alert Boston',
#        'Air Pollution Control', 'Generic Noise Disturbance',
#        'Bridge Maintenance', 'Parking Complaints',
# ...

# %%
month = df['Month'] = df['open_dt'].dt.month

# %%
month.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: open_dt, dtype: int64

# %%
final = pd.merge(df1, month, left_index=True, right_index=True)

# %%
final.head()
# Out:
#             open_dt_x                            neighborhood  \
# 0 2017-01-01 00:33:05  South Boston / South Boston Waterfront
# 1 2017-01-01 01:22:52                           Jamaica Plain
# 2 2017-01-01 01:24:00                           Jamaica Plain
# 3 2017-01-01 02:24:00                                 Roxbury
# 4 2017-01-01 02:27:00                              Dorchester
#
#                              reason  open_dt_y
# 0  Enforcement & Abandoned Vehicles          1
# 1  Enforcement & Abandoned Vehicles          1
# 2                     Street Lights          1
# 3                          Graffiti          1
# 4                           Housing          1

# %%
df = final[["reason", "open_dt_y"]]

# %%
df
# Out:
#                                   reason  open_dt_y
# 0       Enforcement & Abandoned Vehicles          1
# 1       Enforcement & Abandoned Vehicles          1
# 2                          Street Lights          1
# 3                               Graffiti          1
# 4                                Housing          1
# ...                                  ...        ...
# 251490                  Code Enforcement         12
# 251491  Enforcement & Abandoned Vehicles         12
# 251492                  Code Enforcement         12
# 251493                        Sanitation         12
# 251494  Enforcement & Abandoned Vehicles         12
#
# [251495 rows x 2 columns]

# %%
df_2 = df.loc[df['reason'].isin(['Generic Noise Disturbance', 'Noise Disturbance'])]

# %%
df_2
# Out:
#                            reason  open_dt_y
# 109             Noise Disturbance          1
# 4907    Generic Noise Disturbance          1
# 6910            Noise Disturbance          1
# 7591            Noise Disturbance          1
# 7625            Noise Disturbance          1
# ...                           ...        ...
# 243628          Noise Disturbance         12
# 244424          Noise Disturbance         12
# 245761          Noise Disturbance         12
# 247188  Generic Noise Disturbance         12
# 247296          Noise Disturbance         12
#
# [259 rows x 2 columns]

# %%
groupby_df = df_2.groupby('open_dt_y').count()
groupby_df
# Out:
#            reason
# open_dt_y
# 1              10
# 2              21
# 3              11
# 4              22
# 5              30
# 6              16
# 7              28
# 8              38
# 9              33
# 10             22
# 11             16
# 12             12

# %%
df = pd.DataFrame({'month':['Jan', 'Feb', ' Mar', 'April', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec'], 'Noise Complaints':[10, 21, 11, 22, 30, 16, 28, 38, 33, 22, 16, 12]})
ax = df.plot.bar(x='month', y='Noise Complaints', rot=0)

# %%
date['2017'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2017-01-01 00:33:05 to 2017-01-01 02:27:00
# Data columns (total 2 columns):
# neighborhood    5 non-null object
# reason          5 non-null object
# dtypes: object(2)
# memory usage: 120.0+ bytes
